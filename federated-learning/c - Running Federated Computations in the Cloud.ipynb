# %% [markdown]
# # Running Federated Computations in the Cloud

# %% [markdown]
# Let's explore how easy it will be to modify Part A to support predictions in the cloud. We'll point out the differences below.
#
# The first steps are to set up the cloud instances. There are few prerequisites that need to be setup prior to launching the cloud instances. This tutorial uses Google Cloud so you'll need an account set up there and need to have the gcloud command-line tool installed.
#
# See [here](../private-prediction/CLOUD.md) for more details about installing the gcloud command-line tool and launching the instances.
#
# NOTE: If unable to use Google Cloud, you can set the environment variables `INSTANCE_NAMES` and use the script `launch_local_servers.sh`
#
# ```
# export INSTANCE_NAMES="server0 server1 server2 model-owner data-owner-0 data-owner-1 data-owner-2"
# ./launch_local_servers.sh $INSTANCE_NAMES
# ```

# %%
import tensorflow as tf
import tf_encrypted as tfe

config = tfe.RemoteConfig.load("/tmp/config.json")
config.connect_to_cluster()

tfe.set_config(config)
tfe.set_protocol(tfe.protocol.Pond())

from players import BaseModelOwner, BaseDataOwner
from func_lib import default_model_fn, secure_mean, evaluate_classifier
from util import split_dataset
from data_lib import federate_dataset
from download import download_mnist

NUM_DATA_OWNERS = 3
BATCH_SIZE = 256
DATA_ITEMS = 60000
EPOCHS = 5
ROUNDS = EPOCHS * DATA_ITEMS // NUM_DATA_OWNERS // BATCH_SIZE
LEARNING_RATE = 0.01

MODEL_OWNER = "model-owner"
DATA_OWNERS = ["data-owner-0", "data-owner-1", "data-owner-2"]

# %%
class ModelOwner(BaseModelOwner):
  @classmethod
  def model_fn(cls, data_owner):
    return default_model_fn(data_owner)

  @classmethod
  def aggregator_fn(cls, model_gradients, model):
    return secure_mean(model_gradients)

  @classmethod
  def evaluator_fn(cls, model_owner):
    return evaluate_classifier(model_owner)

class DataOwner(BaseDataOwner):
  pass

# %%
simulation_tfrecords = federate_dataset(
    "fashion_mnist:3.0.0", 
    DATA_OWNERS, 
    MODEL_OWNER,
    validation_split=.2,
    gcp_send=True,
)

dataowner_tfrecords = {do: simulation_tfrecords[do] for do in DATA_OWNERS}
validation_tfrecords = simulation_tfrecords.get(MODEL_OWNER, None)
# Out:
# CompletedProcess(args="gcloud compute ssh model-owner --command='mkdir -p /tmp/data'", returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args='gcloud compute scp /tmp/data/fashion_mnist:3.0.0:train:model-owner.tfrecord model-owner:/tmp/data/fashion_mnist:3.0.0:train:model-owner.tfrecord', returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args="gcloud compute ssh data-owner-0 --command='mkdir -p /tmp/data'", returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args='gcloud compute scp /tmp/data/fashion_mnist:3.0.0:train:data-owner-0.tfrecord data-owner-0:/tmp/data/fashion_mnist:3.0.0:train:data-owner-0.tfrecord', returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args="gcloud compute ssh data-owner-1 --command='mkdir -p /tmp/data'", returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args='gcloud compute scp /tmp/data/fashion_mnist:3.0.0:train:data-owner-1.tfrecord data-owner-1:/tmp/data/fashion_mnist:3.0.0:train:data-owner-1.tfrecord', returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args="gcloud compute ssh data-owner-2 --command='mkdir -p /tmp/data'", returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args='gcloud compute scp /tmp/data/fashion_mnist:3.0.0:train:data-owner-2.tfrecord data-owner-2:/tmp/data/fashion_mnist:3.0.0:train:data-owner-2.tfrecord', returncode=0, stdout=b'', stderr=b'')

# %%
model = tf.keras.Sequential((
    tf.keras.layers.Dense(512, input_shape=[None, 28 * 28],
                          activation='relu'),
    tf.keras.layers.Dense(10),
))

model.build()

loss = tf.keras.losses.sparse_categorical_crossentropy
opt = tf.keras.optimizers.Adam(LEARNING_RATE)

# %%
model_owner = ModelOwner(MODEL_OWNER,
                         validation_tfrecords,
                         model, loss,
                         optimizer=opt)

data_owners = [DataOwner(data_owner,
                         dataowner_tfrecords[data_owner],
                         model, loss,
                         optimizer=opt)
              for data_owner in DATA_OWNERS]

# %%
tf.device(data_owners)

# %%
data_owners[0].device._device_name
# Out:
# '/job:tfe/replica:0/task:4/cpu:0'

# %%
dataowner_tfrecords
# Out:
# {'data-owner-0': ['/tmp/data/fashion_mnist:3.0.0:train:data-owner-0.tfrecord'],
#  'data-owner-1': ['/tmp/data/fashion_mnist:3.0.0:train:data-owner-1.tfrecord'],
#  'data-owner-2': ['/tmp/data/fashion_mnist:3.0.0:train:data-owner-2.tfrecord']}

# %%
model_owner.fit(data_owners, rounds=ROUNDS, evaluate_every=10)

print("\nDone training!!")
# Out:
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(124)_update_one_round()
# -> try:  # If the DataOwner implements a model_fn, use it
# (Pdb) l
# 119
# 120  	    # One round is an aggregation over all DataOwners
# 121  	    for owner in data_owners:
# 122  	      import pdb; pdb.set_trace()
# 123
# 124  ->	      try:  # If the DataOwner implements a model_fn, use it
# 125  	        grads = owner.call_model_fn(owner, player_name=owner.player_name,
# 126  	                                    **kwargs)
# 127  	        player_gradients.append(grads)
# 128  	      except NotImplementedError:  # Otherwise, fall back to the ModelOwner's
# 129  	        grads = self.call_model_fn(owner, player_name=owner.player_name,
# (Pdb) n
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(125)_update_one_round()
# -> grads = owner.call_model_fn(owner, player_name=owner.player_name,
# (Pdb) n
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(126)_update_one_round()
# -> **kwargs)
# (Pdb) n
# NotImplementedError
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(126)_update_one_round()
# -> **kwargs)
# (Pdb) l
# 121  	    for owner in data_owners:
# 122  	      import pdb; pdb.set_trace()
# 123
# 124  	      try:  # If the DataOwner implements a model_fn, use it
# 125  	        grads = owner.call_model_fn(owner, player_name=owner.player_name,
# 126  ->	                                    **kwargs)
# 127  	        player_gradients.append(grads)
# 128  	      except NotImplementedError:  # Otherwise, fall back to the ModelOwner's
# 129  	        grads = self.call_model_fn(owner, player_name=owner.player_name,
# 130  	                                   **kwargs)
# 131  	        player_gradients.append(grads)
# (Pdb) n
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(128)_update_one_round()
# -> except NotImplementedError:  # Otherwise, fall back to the ModelOwner's
# (Pdb) n
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(129)_update_one_round()
# -> grads = self.call_model_fn(owner, player_name=owner.player_name,
# (Pdb) n
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(130)_update_one_round()
# -> **kwargs)
# (Pdb) l
# 125  	        grads = owner.call_model_fn(owner, player_name=owner.player_name,
# 126  	                                    **kwargs)
# 127  	        player_gradients.append(grads)
# 128  	      except NotImplementedError:  # Otherwise, fall back to the ModelOwner's
# 129  	        grads = self.call_model_fn(owner, player_name=owner.player_name,
# 130  ->	                                   **kwargs)
# 131  	        player_gradients.append(grads)
# 132
# 133  	      # Fail gracefully
# 134  	      except NotImplementedError: #pylint: disable=duplicate-except
# 135  	        raise UndefinedModelFnError()
# (Pdb) s
# --Call--
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(97)compute_func_wrapper()
# -> @wraps(compute_func)
# (Pdb) l
#  92  	    #   return tf.zeros((2, 2))
#  93  	    actual_compute_func = None
#  94
#  95  	  def decorator(compute_func):
#  96
#  97  ->	    @wraps(compute_func)
#  98  	    def compute_func_wrapper(*compute_func_args, **compute_func_kwargs):
#  99
# 100  	      # Assumer user has passed player_name to decorator. If not, try to recover.
# 101  	      actual_player_name = player_name
# 102  	      if actual_player_name is None:
# (Pdb) compute_func
# <function BaseModelOwner.call_model_fn at 0x12f211b00>
# (Pdb) s
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(101)compute_func_wrapper()
# -> actual_player_name = player_name
# (Pdb) l
#  96
#  97  	    @wraps(compute_func)
#  98  	    def compute_func_wrapper(*compute_func_args, **compute_func_kwargs):
#  99
# 100  	      # Assumer user has passed player_name to decorator. If not, try to recover.
# 101  ->	      actual_player_name = player_name
# 102  	      if actual_player_name is None:
# 103  	        # Maybe user has passed player_name to compute_func as a kwarg
# 104  	        actual_player_name = compute_func_kwargs.get("player_name", None)
# 105  	      if actual_player_name is None:
# 106  	        # Assume compute_func is a method and its instance has some attribute
# (Pdb) player_name
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(102)compute_func_wrapper()
# -> if actual_player_name is None:
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(104)compute_func_wrapper()
# -> actual_player_name = compute_func_kwargs.get("player_name", None)
# (Pdb) l
#  99
# 100  	      # Assumer user has passed player_name to decorator. If not, try to recover.
# 101  	      actual_player_name = player_name
# 102  	      if actual_player_name is None:
# 103  	        # Maybe user has passed player_name to compute_func as a kwarg
# 104  ->	        actual_player_name = compute_func_kwargs.get("player_name", None)
# 105  	      if actual_player_name is None:
# 106  	        # Assume compute_func is a method and its instance has some attribute
# 107  	        # 'player_name'
# 108  	        if compute_func_args:
# 109  	          parent_instance = compute_func_args[0]
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(105)compute_func_wrapper()
# -> if actual_player_name is None:
# (Pdb) actual_player_name
# 'data-owner-0'
# (Pdb) l
# 100  	      # Assumer user has passed player_name to decorator. If not, try to recover.
# 101  	      actual_player_name = player_name
# 102  	      if actual_player_name is None:
# 103  	        # Maybe user has passed player_name to compute_func as a kwarg
# 104  	        actual_player_name = compute_func_kwargs.get("player_name", None)
# 105  ->	      if actual_player_name is None:
# 106  	        # Assume compute_func is a method and its instance has some attribute
# 107  	        # 'player_name'
# 108  	        if compute_func_args:
# 109  	          parent_instance = compute_func_args[0]
# 110  	          actual_player_name = getattr(parent_instance, 'player_name', None)
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(111)compute_func_wrapper()
# -> if actual_player_name is None:
# (Pdb) l
# 106  	        # Assume compute_func is a method and its instance has some attribute
# 107  	        # 'player_name'
# 108  	        if compute_func_args:
# 109  	          parent_instance = compute_func_args[0]
# 110  	          actual_player_name = getattr(parent_instance, 'player_name', None)
# 111  ->	      if actual_player_name is None:
# 112  	        # Fallback to error
# 113  	        raise ValueError("'player_name' not provided. Please provide "
# 114  	                         "'player_name' as a keyword argument to this "
# 115  	                         "function, or as an argument to the "
# 116  	                         "tfe.local_computation decorator.")
# (Pdb) actual_player_name
# 'data-owner-0'
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(118)compute_func_wrapper()
# -> return get_protocol().define_local_computation(
# (Pdb) l
# 113  	        raise ValueError("'player_name' not provided. Please provide "
# 114  	                         "'player_name' as a keyword argument to this "
# 115  	                         "function, or as an argument to the "
# 116  	                         "tfe.local_computation decorator.")
# 117
# 118  ->	      return get_protocol().define_local_computation(
# 119  	          actual_player_name,
# 120  	          compute_func,
# 121  	          arguments=compute_func_args,
# 122  	          **kwargs,
# 123  	      )
# (Pdb) s
# --Call--
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/protocol.py(54)get_protocol()
# -> def get_protocol() -> Optional[Protocol]:
# (Pdb) r
# --Return--
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/protocol.py(60)get_protocol()-><tf_encrypted...t 0x12f1d7b10>
# -> return __PROTOCOL__
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(119)compute_func_wrapper()
# -> actual_player_name,
# (Pdb) l
# 114  	                         "'player_name' as a keyword argument to this "
# 115  	                         "function, or as an argument to the "
# 116  	                         "tfe.local_computation decorator.")
# 117
# 118  	      return get_protocol().define_local_computation(
# 119  ->	          actual_player_name,
# 120  	          compute_func,
# 121  	          arguments=compute_func_args,
# 122  	          **kwargs,
# 123  	      )
# 124
# (Pdb) actual_player_name
# 'data-owner-0'
# (Pdb) compute_func
# <function BaseModelOwner.call_model_fn at 0x12f211b00>
# (Pdb) compute_func_args
# (<__main__.ModelOwner object at 0x12ffbe850>, <__main__.DataOwner object at 0x12ffbe350>)
# (Pdb) compute_func_args[1]
# <__main__.DataOwner object at 0x12ffbe350>
# (Pdb) compute_func_ars[1].player_name
# *** NameError: name 'compute_func_ars' is not defined
# (Pdb) compute_func_args[0].player_name
# 'model-owner'
# (Pdb) compute_func_args[1].player_name
# 'data-owner-0'
# (Pdb) kwargs
# {}
# (Pdb) l
# 125  	    return compute_func_wrapper
# 126
# 127  	  if actual_compute_func is None:
# 128  	    # User has not yet passed a compute_func, so we'll expect them to
# 129  	    # pass it outside of this function's scope (e.g. as a decorator).
# 130  	    return decorator
# 131
# 132  	  # User has already passed a compute_func, so return the decorated version.
# 133  	  return decorator(actual_compute_func)
# 134
# 135
# (Pdb) compute_func_wrapper
# *** NameError: name 'compute_func_wrapper' is not defined
# (Pdb) l
# 136  	def set_protocol(prot: Optional[protocol.Protocol] = None) -> None:
# 137  	  """
# 138  	  Sets the global protocol. See
# 139  	  :class:`~tf_encrypted.protocol.protocol.Protocol` for more info.
# 140
# 141  	  :param ~tf_encrypted.protocol.protocol.Protocol prot: A protocol instance.
# 142  	  """
# 143
# 144  	  # reset all names
# 145  	  for func_name in _all_prot_funcs:
# 146  	    globals()[func_name] = _prot_func_not_implemented
# (Pdb) l
# 147
# 148  	  # add global names according to new protocol
# 149  	  if prot is not None:
# 150  	    methods = inspect.getmembers(prot, predicate=inspect.ismethod)
# 151  	    public_methods = [
# 152  	        method for method in methods if not method[0].startswith('_')]
# 153  	    for name, func in public_methods:
# 154  	      globals()[name] = func
# 155
# 156  	  # record new protocol
# 157  	  protocol.set_protocol(prot)
# (Pdb) l
# 158
# 159
# 160  	def set_config(config: Config) -> None:
# 161  	  # TODO(Morten) re-enable lint after switch to absolute imports
# 162  	  from .config import set_config as set_global_config  # pylint: disable=import-outside-toplevel
# 163
# 164  	  set_global_config(config)
# 165  	  set_protocol(None)
# 166
# 167
# 168  	def global_variables_initializer() -> Optional[tf.Operation]:
# (Pdb) l
# 169  	  prot = protocol.get_protocol()
# 170  	  if prot is not None:
# 171  	    return prot.initializer
# 172  	  return None
# 173
# 174
# 175  	set_protocol(Pond())
# 176
# 177
# 178  	__all__ = [
# 179  	    "LocalConfig",
# (Pdb) l
# 180  	    "RemoteConfig",
# 181  	    "EagerLocalConfig",
# 182  	    "set_tfe_events_flag",
# 183  	    "set_tfe_trace_flag",
# 184  	    "set_log_directory",
# 185  	    "get_config",
# 186  	    "set_config",
# 187  	    "get_protocol",
# 188  	    "set_protocol",
# 189  	    "Session",
# 190  	    "player",
# (Pdb) l
# 191  	    "protocol",
# 192  	    "layers",
# 193  	    "convert",
# 194  	    "operations",
# 195  	    "global_variables_initializer",
# 196  	    "keras",
# 197  	    "queue",
# 198  	    "serving",
# 199  	]
# [EOF]
# (Pdb) l
# [EOF]
# (Pdb) l
# [EOF]
# (Pdb) l
# [EOF]
# (Pdb) l
# [EOF]
# (Pdb) s
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(120)compute_func_wrapper()
# -> compute_func,
# (Pdb) l
# 115  	                         "function, or as an argument to the "
# 116  	                         "tfe.local_computation decorator.")
# 117
# 118  	      return get_protocol().define_local_computation(
# 119  	          actual_player_name,
# 120  ->	          compute_func,
# 121  	          arguments=compute_func_args,
# 122  	          **kwargs,
# 123  	      )
# 124
# 125  	    return compute_func_wrapper
# (Pdb) s
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(121)compute_func_wrapper()
# -> arguments=compute_func_args,
# (Pdb) s
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py(122)compute_func_wrapper()
# -> **kwargs,
# (Pdb) s
# --Call--
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(517)define_local_computation()
# -> def define_local_computation(
# (Pdb) l
# 512  	          return [helper(v) for v in inputs]
# 513
# 514  	        raise TypeError(("Don't know how to handle inputs "
# 515  	                         "of type {}").format(type(inputs)))
# 516
# 517  ->	  def define_local_computation(
# 518  	      self,
# 519  	      player,
# 520  	      computation_fn,
# 521  	      arguments=None,
# 522  	      apply_scaling=True,
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(538)define_local_computation()
# -> factory = factory or self.tensor_factory
# (Pdb) l
# 533  	    :param name_scope: Optional name to give to this node in the graph.
# 534  	    :param masked: Whether or not to produce masked outputs.
# 535  	    :param factory: Backing tensor type to use for outputs.
# 536  	    """  # noqa:E501
# 537
# 538  ->	    factory = factory or self.tensor_factory
# 539
# 540  	    if isinstance(player, str):
# 541  	      player = get_config().get_player(player)
# 542  	    assert isinstance(player, Player)
# 543
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(540)define_local_computation()
# -> if isinstance(player, str):
# (Pdb) factory
# <tf_encrypted.tensor.native.native_factory.<locals>.Factory object at 0x12f0ca4d0>
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(541)define_local_computation()
# -> player = get_config().get_player(player)
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(542)define_local_computation()
# -> assert isinstance(player, Player)
# (Pdb) player
# <tf_encrypted.player.player.Player object at 0x12f1da2d0>
# (Pdb) player.player_name
# *** AttributeError: 'Player' object has no attribute 'player_name'
# (Pdb) player.name
# 'data-owner-0'
# (Pdb) l
# 537
# 538  	    factory = factory or self.tensor_factory
# 539
# 540  	    if isinstance(player, str):
# 541  	      player = get_config().get_player(player)
# 542  ->	    assert isinstance(player, Player)
# 543
# 544  	    def share_output(v: tf.Tensor):
# 545  	      assert v.shape.is_fully_defined(), ("Shape of return value '{}' on '{}' "
# 546  	                                          "not fully defined").format(
# 547  	                                              name_scope if name_scope else "",
# (Pdb) l
# 548  	                                              player.name,
# 549  	                                          )
# 550
# 551  	      enc = self._encode(v, apply_scaling, tf_int_type=factory.native_type)
# 552  	      w = factory.tensor(enc)
# 553  	      x = self._share_and_wrap(w, apply_scaling)
# 554
# 555  	      if not masked:
# 556  	        return x
# 557  	      with tf.compat.v1.name_scope("local_mask"):
# 558  	        a0 = factory.sample_uniform(v.shape)
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(544)define_local_computation()
# -> def share_output(v: tf.Tensor):
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(564)define_local_computation()
# -> def reconstruct_input(x):
# (Pdb) l
# 559  	        a1 = factory.sample_uniform(v.shape)
# 560  	        a = a0 + a1
# 561  	        alpha = w - a
# 562  	      return PondMaskedTensor(self, x, a, a0, a1, alpha, alpha, apply_scaling)
# 563
# 564  ->	    def reconstruct_input(x):
# 565
# 566  	      if not isinstance(x, (AbstractTensor, PondTensor)):
# 567  	        return x
# 568
# 569  	      if isinstance(x, PondPublicTensor):
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(589)define_local_computation()
# -> with tf.name_scope(name_scope if name_scope else "local-computation"):
# (Pdb) l
# 584  	        return v
# 585
# 586  	      raise TypeError(("Don't know how to process input argument "
# 587  	                       "of type {}").format(type(x)))
# 588
# 589  ->	    with tf.name_scope(name_scope if name_scope else "local-computation"):
# 590
# 591  	      with tf.device(player.device_name):
# 592  	        if arguments is None:
# 593  	          inputs = []
# 594  	        else:
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(591)define_local_computation()
# -> with tf.device(player.device_name):
# (Pdb) l
# 586  	      raise TypeError(("Don't know how to process input argument "
# 587  	                       "of type {}").format(type(x)))
# 588
# 589  	    with tf.name_scope(name_scope if name_scope else "local-computation"):
# 590
# 591  ->	      with tf.device(player.device_name):
# 592  	        if arguments is None:
# 593  	          inputs = []
# 594  	        else:
# 595  	          if not isinstance(arguments, (list, tuple)):
# 596  	            arguments = [arguments]
# (Pdb) player.device_name
# '/job:tfe/replica:0/task:4/cpu:0'
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(592)define_local_computation()
# -> if arguments is None:
# (Pdb) l
# 587  	                       "of type {}").format(type(x)))
# 588
# 589  	    with tf.name_scope(name_scope if name_scope else "local-computation"):
# 590
# 591  	      with tf.device(player.device_name):
# 592  ->	        if arguments is None:
# 593  	          inputs = []
# 594  	        else:
# 595  	          if not isinstance(arguments, (list, tuple)):
# 596  	            arguments = [arguments]
# 597
# (Pdb) arguments
# (<__main__.ModelOwner object at 0x12ffbe850>, <__main__.DataOwner object at 0x12ffbe350>)
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(595)define_local_computation()
# -> if not isinstance(arguments, (list, tuple)):
# (Pdb) l
# 590
# 591  	      with tf.device(player.device_name):
# 592  	        if arguments is None:
# 593  	          inputs = []
# 594  	        else:
# 595  ->	          if not isinstance(arguments, (list, tuple)):
# 596  	            arguments = [arguments]
# 597
# 598  	          inputs = tf.nest.map_structure(
# 599  	              reconstruct_input, arguments)
# 600
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(598)define_local_computation()
# -> inputs = tf.nest.map_structure(
# (Pdb) l
# 593  	          inputs = []
# 594  	        else:
# 595  	          if not isinstance(arguments, (list, tuple)):
# 596  	            arguments = [arguments]
# 597
# 598  ->	          inputs = tf.nest.map_structure(
# 599  	              reconstruct_input, arguments)
# 600
# 601  	        outputs = computation_fn(*inputs)
# 602
# 603  	        if outputs is None:
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(599)define_local_computation()
# -> reconstruct_input, arguments)
# (Pdb) arguments
# (<__main__.ModelOwner object at 0x12ffbe850>, <__main__.DataOwner object at 0x12ffbe350>)
# (Pdb) inputs
# *** NameError: name 'inputs' is not defined
# (Pdb) p inputs
# *** NameError: name 'inputs' is not defined
# (Pdb) l
# 594  	        else:
# 595  	          if not isinstance(arguments, (list, tuple)):
# 596  	            arguments = [arguments]
# 597
# 598  	          inputs = tf.nest.map_structure(
# 599  ->	              reconstruct_input, arguments)
# 600
# 601  	        outputs = computation_fn(*inputs)
# 602
# 603  	        if outputs is None:
# 604  	          return None
# (Pdb) n
# > /Users/jasonmancuso/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py(601)define_local_computation()
# -> outputs = computation_fn(*inputs)
# (Pdb) p inputs
# (<__main__.ModelOwner object at 0x12ffbe850>, <__main__.DataOwner object at 0x12ffbe350>)
# (Pdb) inputs[0]
# <__main__.ModelOwner object at 0x12ffbe850>
# (Pdb) l
# 596  	            arguments = [arguments]
# 597
# 598  	          inputs = tf.nest.map_structure(
# 599  	              reconstruct_input, arguments)
# 600
# 601  ->	        outputs = computation_fn(*inputs)
# 602
# 603  	        if outputs is None:
# 604  	          return None
# 605
# 606  	        if isinstance(outputs, tf.Operation):
# (Pdb) s
# --Call--
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(112)call_model_fn()
# -> @tfe.local_computation
# (Pdb) l
# 107
# 108  	  @pin_to_owner
# 109  	  def _call_evaluator_fn(self):
# 110  	    return self.evaluator_fn(self)
# 111
# 112  ->	  @tfe.local_computation
# 113  	  def call_model_fn(self, batches_or_owner):
# 114  	    return self.model_fn(batches_or_owner)
# 115
# 116  	  def _update_one_round(self, data_owners, **kwargs):
# 117  	    """ Updates after one FL round """
# (Pdb) n
# > /Users/jasonmancuso/tf-world/federated-learning/players.py(114)call_model_fn()
# -> return self.model_fn(batches_or_owner)
# (Pdb) s
# --Call--
# > <ipython-input-2-6843f18b08cd>(2)model_fn()
# -> @classmethod
# (Pdb) l
#   1  	class ModelOwner(BaseModelOwner):
#   2  ->	  @classmethod
#   3  	  def model_fn(cls, data_owner):
#   4  	    return default_model_fn(data_owner)
#   5
#   6  	  @classmethod
#   7  	  def aggregator_fn(cls, model_gradients, model):
#   8  	    return secure_mean(model_gradients)
#   9
#  10  	  @classmethod
#  11  	  def evaluator_fn(cls, model_owner):
# (Pdb) s
# > <ipython-input-2-6843f18b08cd>(4)model_fn()
# -> return default_model_fn(data_owner)
# (Pdb) s
# --Call--
# > /Users/jasonmancuso/tf-world/federated-learning/func_lib.py(9)default_model_fn()
# -> def default_model_fn(data_owner):
# (Pdb) l
#   4  	import tf_encrypted as tfe
#   5
#   6
#   7  	### Example model_fns ###
#   8
#   9  ->	def default_model_fn(data_owner):
#  10  	  """Runs a single training step!"""
#  11  	  x, y = next(data_owner.dataset)
#  12
#  13  	  with tf.name_scope("gradient_computation"):
#  14
# (Pdb) data_owner.dataset
# <tensorflow.python.data.ops.iterator_ops.IteratorV2 object at 0x12f9724d0>
# (Pdb) n
# > /Users/jasonmancuso/tf-world/federated-learning/func_lib.py(11)default_model_fn()
# -> x, y = next(data_owner.dataset)
# (Pdb) n
# tensorflow.python.framework.errors_impl.NotFoundError: /tmp/data/fashion_mnist:3.0.0:train:data-owner-0.tfrecord; No such file or directory
# Additional GRPC error information:
# {"created":"@1572310627.271138000","description":"Error received from peer","file":"external/grpc/src/core/lib/surface/call.cc","file_line":1039,"grpc_message":"/tmp/data/fashion_mnist:3.0.0:train:data-owner-0.tfrecord; No such file or directory","grpc_status":5} [Op:IteratorGetNextSync]
# > /Users/jasonmancuso/tf-world/federated-learning/func_lib.py(11)default_model_fn()
# -> x, y = next(data_owner.dataset)
# (Pdb) q
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/tf-world/federated-learning/players.py in _update_one_round(self, data_owners, **kwargs)
#     125         grads = owner.call_model_fn(owner, player_name=owner.player_name,
# --> 126                                     **kwargs)
#     127         player_gradients.append(grads)
#
# ~/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py in compute_func_wrapper(*compute_func_args, **compute_func_kwargs)
#     121           arguments=compute_func_args,
# --> 122           **kwargs,
#     123       )
#
# ~/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py in define_local_computation(self, player, computation_fn, arguments, apply_scaling, name_scope, masked, factory)
#     600
# --> 601         outputs = computation_fn(*inputs)
#     602
#
# ~/tf-world/federated-learning/players.py in call_model_fn(self, batches_or_owner, *args, **kwargs)
#     170   def call_model_fn(self, batches_or_owner, *args, **kwargs):
# --> 171     return self.model_fn(batches_or_owner, *args, **kwargs)
#     172
#
# ~/tf-world/federated-learning/players.py in model_fn(cls, batches_or_owner, *args, **kwargs)
#     174   def model_fn(cls, batches_or_owner, *args, **kwargs):
# --> 175     raise NotImplementedError()
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-10-f2dbe0af67db> in <module>
# ----> 1 model_owner.fit(data_owners, rounds=ROUNDS, evaluate_every=10)
#       2
#       3 print("\nDone training!!")
#
# ~/tf-world/federated-learning/players.py in fit(self, data_owners, rounds, evaluate, evaluate_every, **model_fn_params)
#      66           **model_fn_params):
#      67     self._runner(
# ---> 68         data_owners, rounds, evaluate, evaluate_every, **model_fn_params,
#      69     )
#      70
#
# ~/tf-world/federated-learning/players.py in _runner(self, data_owners, rounds, evaluate, evaluate_every, **kwargs)
#      89     for r in range(rounds):
#      90       # Train one step
# ---> 91       self._update_one_round(data_owners, **kwargs)
#      92
#      93       # Broadcast master model
#
# ~/tf-world/federated-learning/players.py in _update_one_round(self, data_owners, **kwargs)
#     128       except NotImplementedError:  # Otherwise, fall back to the ModelOwner's
#     129         grads = self.call_model_fn(owner, player_name=owner.player_name,
# --> 130                                    **kwargs)
#     131         player_gradients.append(grads)
#     132
#
# ~/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/__init__.py in compute_func_wrapper(*compute_func_args, **compute_func_kwargs)
#     120           compute_func,
#     121           arguments=compute_func_args,
# --> 122           **kwargs,
#     123       )
#     124
#
# ~/tf-world/venv/lib/python3.7/site-packages/tf_encrypted/protocol/pond/pond.py in define_local_computation(self, player, computation_fn, arguments, apply_scaling, name_scope, masked, factory)
#     599               reconstruct_input, arguments)
#     600
# --> 601         outputs = computation_fn(*inputs)
#     602
#     603         if outputs is None:
#
# ~/tf-world/federated-learning/players.py in call_model_fn(self, batches_or_owner)
#     112   @tfe.local_computation
#     113   def call_model_fn(self, batches_or_owner):
# --> 114     return self.model_fn(batches_or_owner)
#     115
#     116   def _update_one_round(self, data_owners, **kwargs):
#
# <ipython-input-2-6843f18b08cd> in model_fn(cls, data_owner)
#       2   @classmethod
#       3   def model_fn(cls, data_owner):
# ----> 4     return default_model_fn(data_owner)
#       5
#       6   @classmethod
#
# ~/tf-world/federated-learning/func_lib.py in default_model_fn(data_owner)
#       9 def default_model_fn(data_owner):
#      10   """Runs a single training step!"""
# ---> 11   x, y = next(data_owner.dataset)
#      12
#      13   with tf.name_scope("gradient_computation"):
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
# ---> 94             return self.dispatch_exception(frame, arg)
#      95         if event == 'c_call':
#      96             return self.trace_dispatch
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/bdb.py in dispatch_exception(self, frame, arg)
#     172                     and arg[0] is StopIteration and arg[2] is None):
#     173                 self.user_exception(frame, arg)
# --> 174                 if self.quitting: raise BdbQuit
#     175         # Stop at the StopIteration or GeneratorExit exception when the user
#     176         # has set stopframe in a generator by issuing a return command, or a
#
# BdbQuit:
